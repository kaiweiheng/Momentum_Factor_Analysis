# %%
import sys
sys.path.append("./src")
from Experiment import Experiment

product_list = ["QQQ","SPY","MSFT","TSM","PDD","AMD","CVX","XOM","TQQQ","BILI","NVDA","BABA"]
# product_list = ["QQQ","SPY","TSLA","TSM","MSFT","BILI","PDD","XOM","CVX"]
# product_list = ["QQQ","TQQQ","SPY","AAPL","TSM"] #,"0823.HK","2800.HK"
for p in product_list:
    exp = Experiment("LongSig", p) 
    _, _ = exp.MakePredictionExperiment()
# Out:
# Loading existed dataset from ./data/QQQ_LongSig.pkl
#
# QQQ_training total 4014, tp 620, fp 193, tn 1814, fn 1387
#
# QQQ_validation total 1004, tp 152, fp 42, tn 460, fn 350
#
# QQQ_testing total 255, tp 46, fp 15, tn 75, fn 119
#
# +-------------+--------+-----------+--------+
# | QQQ_LongSig |  Acc   | Precision | Recall |
# +-------------+--------+-----------+--------+
# |   Training  | 0.6064 |   0.7626  | 0.3089 |
# |  Validation | 0.6096 |   0.7835  | 0.3089 |
# |   Testing   | 0.4745 |   0.7541  | 0.3089 |
# +-------------+--------+-----------+--------+
# Loading existed dataset from ./data/SPY_LongSig.pkl
#
# SPY_training total 2982, tp 446, fp 110, tn 1381, fn 1045
#
# SPY_validation total 746, tp 122, fp 23, tn 350, fn 251
#
# SPY_testing total 255, tp 66, fp 33, tn 82, fn 74
#
# +-------------+--------+-----------+--------+
# | SPY_LongSig |  Acc   | Precision | Recall |
# +-------------+--------+-----------+--------+
# |   Training  | 0.6127 |   0.8022  | 0.2991 |
# ...
