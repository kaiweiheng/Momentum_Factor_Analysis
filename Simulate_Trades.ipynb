# %%
import sys
sys.path.append("./src")

from Assessment import Assessment
from Simulator import Simulator


product_list = ["QQQ","SPY","TSM","PDD","AMD","CVX","XOM"]
# product_list = ["QQQ","SPY","TSLA","TSM","MSFT","BILI","PDD","XOM","CVX"]
# "BILI","NVDA","BABA","OVV","FSLR","HUBB"

# product_list = [""]
# product_list = ["QQQ","SPY","TSM","CVX","XOM"]
# product_list = ["QQQ","SPY","TSM"]
sim = Simulator(20000,0.0075,product_list)
_, _ = sim.Simulate()


for p in product_list:
    sim = Simulator(20000,0.0075,[p])
    _, _ = sim.Simulate()
# Out:
# Loading existed dataset from ./data/QQQ_LongSig.pkl
#
# QQQ_training total 4016, tp 608, fp 199, tn 1809, fn 1400
#
# QQQ_validation total 1004, tp 147, fp 42, tn 460, fn 355
#
# QQQ_testing total 255, tp 37, fp 14, tn 75, fn 129
#
# +-------------+--------+-----------+--------+
# | QQQ_LongSig |  Acc   | Precision | Recall |
# +-------------+--------+-----------+--------+
# |   Training  | 0.6018 |   0.7534  | 0.3028 |
# |  Validation | 0.6046 |   0.7778  | 0.3028 |
# |   Testing   | 0.4392 |   0.7255  | 0.3028 |
# +-------------+--------+-----------+--------+
# Loading existed dataset from ./data/SPY_LongSig.pkl
#
# SPY_training total 2986, tp 464, fp 100, tn 1393, fn 1029
#
# SPY_validation total 746, tp 120, fp 25, tn 348, fn 253
#
# SPY_testing total 255, tp 72, fp 37, tn 77, fn 69
#
# +-------------+--------+-----------+--------+
# | SPY_LongSig |  Acc   | Precision | Recall |
# +-------------+--------+-----------+--------+
# |   Training  | 0.6219 |   0.8227  | 0.3108 |
# ...
